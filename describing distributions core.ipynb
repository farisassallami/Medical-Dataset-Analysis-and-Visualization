# %% [markdown]
# Name: Faris Assallami

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/Users/faris/Downloads/data (5).csv')

# %%
df.head()
# Out:
#   State       Lat       Lng      Area  Children  Age    Income   Marital  \
# 0    AL  34.34960 -86.72508  Suburban       1.0   53  86575.93  Divorced
# 1    FL  30.84513 -85.22907     Urban       3.0   51  46805.99   Married
# 2    SD  43.54321 -96.63772  Suburban       3.0   53  14370.14   Widowed
# 3    MN  43.89744 -93.51479  Suburban       0.0   78  39741.49   Married
# 4    VA  37.59894 -76.88958     Rural       1.0   22   1209.56   Widowed
#
#    Gender  ReAdmis  ...  Hyperlipidemia  BackPain  Anxiety  Allergic_rhinitis  \
# 0    Male        0  ...             0.0       1.0      1.0                1.0
# 1  Female        0  ...             0.0       0.0      0.0                0.0
# 2  Female        0  ...             0.0       0.0      0.0                0.0
# 3    Male        0  ...             0.0       0.0      0.0                0.0
# 4  Female        0  ...             1.0       0.0      0.0                1.0
#
# ...

# %%
VitD_levels = df['VitD_levels']
Doc_visits = df['Doc_visits']
TotalCharge = df['TotalCharge']

# %% [markdown]
# # 1-  Plot a histogram with a kde
#
#     Add a line for the mean (red)
#
#     Add a line for the median (green)
#
#     Add a line for for +1 std from the mean (black)
#
#     Add a line for the - 1 std from the mean (black)
#
#     Highlight the range between +1 and =1 std (yellow)

# %% [markdown]
# ## Vitamin D levels

# %%
col = 'VitD_levels'

# Find the mean
mean = df['Income'].mean()

# Find the median
mean = df['Income'].median()


feature = df[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title(f'{col}')
ax.legend();

# %% [markdown]
# Is it Discrete or Continuous?
#    - continuous, because there is no gap in the bar plot
#
# Does it have a skew? If so, which direction (+/-)
#    - no skew, the data seems to be normally distributed
#
# What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
#    - the kurtosis displayed is mesokurtic since it is normally distributed

# %% [markdown]
# ## Doctor visits

# %%
col = 'Doc_visits'

# Find the mean
mean = df['Income'].mean()

# Find the median
mean = df['Income'].median()


feature = df[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title(f'{col}')
ax.legend();

# %% [markdown]
# Is it Discrete or Continuous?
#    - discrete, because there are gaps in the bar plot
#
# Does it have a skew? If so, which direction (+/-)
#    - there seems to be a tiny positive skew towards the right because of a small outlier
#
# What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
#    - the kurtosis displayed is mesokurtic

# %% [markdown]
# ## Total Charge

# %%
col = 'TotalCharge'

# Find the mean
mean = df['Income'].mean()

# Find the median
mean = df['Income'].median()


feature = df[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title(f'{col}')
ax.legend();

# %% [markdown]
# Is it Discrete or Continuous?
#    - continuous, because there is no gap in the bar plot
#
# Does it have a skew? If so, which direction (+/-)
#    - yes there is a skew in the positive direction
#
# What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
#    - the kurtosis displayed is mesokurtic
